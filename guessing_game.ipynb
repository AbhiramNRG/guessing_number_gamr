# %% [markdown]
# # Guessing Game
# You'll create a program that will generate a random number and then ask the user to guess the number. In addition, your program will tell them if they are too high or too low when they guess wrong.
#
# ![CODE3_ArrayArithmetic_1into2.png](data:image/png;base64,...)

# %%
# Create your program here.
import random

# %%
def random_number():
    randNum = random.randint(1,...)
    return(randNum)

random_number()
